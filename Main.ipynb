# %%
import LUXWM

# %%
LUXWM.Process_Batch('Inputs/Tunnel/', Quiet = True, SeriesTitle= "", Idempotence = True)
# Out:
# Tl00003.jpeg
# None
# 2022:12:01 11:36
# Resizing for social media.
# Light
# Watermark Size 750
# Tl00002.jpeg
# None
# 2022:06:14 07:05
# Resizing for social media.
# Dark
# Watermark Size 750
# Tl00004.jpeg
# None
# 2022:07:07 09:00
# Resizing for social media.
# Light
# Watermark Size 667
# Tl00001.jpeg
# None
# 2022:06:19 17:57
# Resizing for social media.
# Dark
# Watermark Size 750
